# %%
# Create a set
s = {1,2,3,4,5}
print(s)
print(type(s))
# Out:
# {1, 2, 3, 4, 5}
# <class 'set'>

# %%
s.add(7)
print(s)
s.add(7)
print(s)
# Out:
# {1, 2, 3, 4, 5, 7}
# {1, 2, 3, 4, 5, 7}

# %%
s.remove(4)
print(s)
# Out:
# {1, 2, 3, 5, 7}

# %%
s.remove(4)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 s.remove(4)
#
# KeyError: 4

# %%
s.discard(4) # This will not give error
print(s)
# Out:
# {1, 2, 3, 5, 7}

# %%
print(s.pop())
print(s)
# Out:
# 2
# {3, 5, 7}

# %%
s.clear()
print(s)
# Out:
# set()

# %%
# Set membership test
s = {1,2,3,4,5}
print(1 in s)
print(6 in s)
print(6 not in s)
# Out:
# True
# False
# True

# %%
# Mathematical Operations
s1 = {1,2,3,4,5}
s2 = {4,5,6,7,8}

print(s1.union(s2))
print(s1.intersection(s2))
print(s1.difference(s2))
print(s2.difference(s1))
print(s1.symmetric_difference(s2))
s1.intersection_update(s2)
print(s1)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}
# {4, 5}
# {1, 2, 3}
# {8, 6, 7}
# {1, 2, 3, 6, 7, 8}
# {4, 5}

# %%
# Sets methods
s1 = {1,2,3,4,5,6,7,8}
s2 = {4,5,6,7,8}
print(s1.isdisjoint(s2))
print(s1.issubset(s2))
print(s1.issuperset(s2))
# Out:
# False
# False
# True

# %%
lst = [1,2,3,4,5,2,2,4,5]
print(lst)
print(set(lst))
# Out:
# [1, 2, 3, 4, 5, 2, 2, 4, 5]
# {1, 2, 3, 4, 5}

# %%
text = "Hello world Hello"
print(text)
words = text.split()
print(set(words))
print(len(set(words)))
print(words)
# Out:
# hello world hello
# Hello world Hello

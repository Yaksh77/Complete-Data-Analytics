# %%
import os 
cwd = os.getcwd()
print(cwd)
# Out:
# y:\Data Analytics\1.Python\4.Python Deep

# %%
# Create a new directory

import os
os.mkdir("new_directory")

# %%
os.listdir('.')
os.listdir()
# Out:
# ['4.1-import.ipynb',
#  '4.2-StandardLibrary.ipynb',
#  '4.3-FileOperations.ipynb',
#  '4.4-FilePathOperations.ipynb',
#  'destination.txt',
#  'example.bin',
#  'example.csv',
#  'example.txt',
#  'new_directory',
#  'package',
#  'source.txt']

# %%
# Joining Paths

dir_name = 'folder'
file_name = 'file.txt'
file_path = os.path.join(dir_name, file_name)
print(file_path)
# Out:
# folder\file.txt

# %%
dir_name = 'folder'
file_name = 'file.txt'
file_path = os.path.join(os.getcwd(), dir_name, file_name)
print(file_path)
# Out:
# y:\Data Analytics\1.Python\4.Python Deep\folder\file.txt

# %%
path = 'example1.txt'

if os.path.exists(path):
    print('File exists')
else:
    print('File does not exist')
# Out:
# File does not exist

# %%
import os

path = "example.txt"

if os.path.isfile(path):
    print("Path is a file")
elif os.path.isdir(path):
    print("Path is a directory")
else:
    print("Path does not exist")
# Out:
# Path is a file

# %%
# Getting the absolute path
relative_path = "example.txt"
absolute_path = os.path.abspath(relative_path)
print(absolute_path)
# Out:
# y:\Data Analytics\1.Python\4.Python Deep\example.txt
